# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/nicholas/Downloads/carpark.csv")

# %%
df
# Out:
#      car_park_no                                      address     x_coord  \
# 0            ACB  BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK  30314.7936
# 1            ACM                    BLK 98A ALJUNIED CRESCENT  33758.4143
# 2            AH1                          BLK 101 JALAN DUSUN  29257.7203
# 3           AK19               BLOCK 253 ANG MO KIO STREET 21  28185.4359
# 4           AK31                 BLK 302/348 ANG MO KIO ST 31  29482.0290
# ...          ...                                          ...         ...
# 2176        Y77M                      BLK 461 YISHUN AVENUE 6  29850.1522
# 2177        Y78M                         BLK 468 YISHUN ST 43  30057.2209
# 2178          Y8     BLK 731/746 YISHUN STREET 71,72/AVENUE 5  27772.9219
# 2179        Y82M                         BLK 478 YISHUN ST 42  29935.5818
# 2180          Y9                 BLK 747/752 YISHUN STREET 72  28077.2305
#
#          y_coord          car_park_type type_of_parking_system  \
# ...

# %%
new_df = df[["x_coord","y_coord"]]

# %%
new_df
# Out:
#          x_coord     y_coord
# 0     30314.7936  31490.4942
# 1     33758.4143  33695.5198
# 2     29257.7203  34500.3599
# 3     28185.4359  39012.6664
# 4     29482.0290  38684.1754
# ...          ...         ...
# 2176  29850.1522  45576.0125
# 2177  30057.2209  45166.4820
# 2178  27772.9219  45686.2734
# 2179  29935.5818  45679.7181
# 2180  28077.2305  45507.8047
#
# [2181 rows x 2 columns]

# %%
new_df["coordinates"] = 0
# Out:
# /var/folders/pc/6ptp7l_n5dv0mgqvds_4y2fr0000gn/T/ipykernel_1874/3596023912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["coordinates"] = 0

# %%
new_df
# Out:
#          x_coord     y_coord  coordinates
# 0     30314.7936  31490.4942            0
# 1     33758.4143  33695.5198            0
# 2     29257.7203  34500.3599            0
# 3     28185.4359  39012.6664            0
# 4     29482.0290  38684.1754            0
# ...          ...         ...          ...
# 2176  29850.1522  45576.0125            0
# 2177  30057.2209  45166.4820            0
# 2178  27772.9219  45686.2734            0
# 2179  29935.5818  45679.7181            0
# 2180  28077.2305  45507.8047            0
#
# [2181 rows x 3 columns]

# %%
new_df["coordinates"] = new_df[["x_coord","y_coord"]].apply(tuple,axis=1)
# Out:
# /var/folders/pc/6ptp7l_n5dv0mgqvds_4y2fr0000gn/T/ipykernel_1874/2395298518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["coordinates"] = new_df[["x_coord","y_coord"]].apply(tuple,axis=1)

# %%
new_df
# Out:
#          x_coord     y_coord               coordinates
# 0     30314.7936  31490.4942  (30314.7936, 31490.4942)
# 1     33758.4143  33695.5198  (33758.4143, 33695.5198)
# 2     29257.7203  34500.3599  (29257.7203, 34500.3599)
# 3     28185.4359  39012.6664  (28185.4359, 39012.6664)
# 4     29482.0290  38684.1754   (29482.029, 38684.1754)
# ...          ...         ...                       ...
# 2176  29850.1522  45576.0125  (29850.1522, 45576.0125)
# 2177  30057.2209  45166.4820   (30057.2209, 45166.482)
# 2178  27772.9219  45686.2734  (27772.9219, 45686.2734)
# 2179  29935.5818  45679.7181  (29935.5818, 45679.7181)
# 2180  28077.2305  45507.8047  (28077.2305, 45507.8047)
#
# [2181 rows x 3 columns]

# %%
new_df = df[["address","x_coord","y_coord"]]

# %%
new_df
# Out:
#                                           address     x_coord     y_coord
# 0     BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK  30314.7936  31490.4942
# 1                       BLK 98A ALJUNIED CRESCENT  33758.4143  33695.5198
# 2                             BLK 101 JALAN DUSUN  29257.7203  34500.3599
# 3                  BLOCK 253 ANG MO KIO STREET 21  28185.4359  39012.6664
# 4                    BLK 302/348 ANG MO KIO ST 31  29482.0290  38684.1754
# ...                                           ...         ...         ...
# 2176                      BLK 461 YISHUN AVENUE 6  29850.1522  45576.0125
# 2177                         BLK 468 YISHUN ST 43  30057.2209  45166.4820
# 2178     BLK 731/746 YISHUN STREET 71,72/AVENUE 5  27772.9219  45686.2734
# 2179                         BLK 478 YISHUN ST 42  29935.5818  45679.7181
# 2180                 BLK 747/752 YISHUN STREET 72  28077.2305  45507.8047
#
# [2181 rows x 3 columns]

# %%
import geopandas as gpd

# %%
gdf = gpd.GeoDataFrame(
    new_df, geometry=gpd.points_from_xy(new_df["x_coord"], new_df["y_coord"]))

# %%
import matplotlib.pyplot as plt

# %%
gdf
# Out:
#                                           address     x_coord     y_coord  \
# 0     BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK  30314.7936  31490.4942
# 1                       BLK 98A ALJUNIED CRESCENT  33758.4143  33695.5198
# 2                             BLK 101 JALAN DUSUN  29257.7203  34500.3599
# 3                  BLOCK 253 ANG MO KIO STREET 21  28185.4359  39012.6664
# 4                    BLK 302/348 ANG MO KIO ST 31  29482.0290  38684.1754
# ...                                           ...         ...         ...
# 2176                      BLK 461 YISHUN AVENUE 6  29850.1522  45576.0125
# 2177                         BLK 468 YISHUN ST 43  30057.2209  45166.4820
# 2178     BLK 731/746 YISHUN STREET 71,72/AVENUE 5  27772.9219  45686.2734
# 2179                         BLK 478 YISHUN ST 42  29935.5818  45679.7181
# 2180                 BLK 747/752 YISHUN STREET 72  28077.2305  45507.8047
#
#                          geometry
# 0     POINT (30314.794 31490.494)
# ...

# %%
world
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pc/6ptp7l_n5dv0mgqvds_4y2fr0000gn/T/ipykernel_1874/4177685540.py in <module>
# ----> 1 world
#
# NameError: name 'world' is not defined

# %%
singapore = world.loc[world['name'] == 'Singapore']

# %%
singapore
# Out:
# Empty GeoDataFrame
# Columns: [pop_est, continent, name, iso_a3, gdp_md_est, geometry]
# Index: []

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# We restrict to South America.
ax = world["name" == 'Singapore'].plot(
    color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dataset = gpd.read_file("https://github.com/honcheng/world.geo.json/raw/e7114a406a3c2a66a54e59be8f419b14f84017fa/countries.geo.json")

# %%
dataset
# Out:
#       id                  name  \
# 0    AFG           Afghanistan
# 1    AGO                Angola
# 2    ALB               Albania
# 3    ARE  United Arab Emirates
# 4    ARG             Argentina
# ..   ...                   ...
# 176  PSE             West Bank
# 177  YEM                 Yemen
# 178  ZAF          South Africa
# 179  ZMB                Zambia
# 180  ZWE              Zimbabwe
#
#                                               geometry
# 0    POLYGON ((61.21082 35.65007, 62.23065 35.27066...
# 1    MULTIPOLYGON (((16.32653 -5.87747, 16.57318 -6...
# 2    POLYGON ((20.59025 41.85540, 20.46317 41.51509...
# 3    POLYGON ((51.57952 24.24550, 51.75744 24.29407...
# 4    MULTIPOLYGON (((-65.50000 -55.20000, -66.45000...
# ..                                                 ...
# 176  POLYGON ((35.54566 32.39399, 35.54525 31.78251...
# 177  POLYGON ((53.10857 16.65105, 52.38521 16.38241...
# 178  POLYGON ((31.52100 -29.25739, 31.32556 -29.401...
# ...

# %%
dataset.plot(cmap='hsv',edgecolor = 'black',column = 'name')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/nicholas/Downloads/farmboxtrial.csv")

# %%
df1
# Out:
#    Humidity = 70.00 %  Temperature = 22.00 C  Light = 285 Lx  Soil moisture = -1.00 % Datetime: 220817_1216
# 0   Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 1   Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 2   Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 3   Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 4   Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# ..                                                ...
# 94  Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 95  Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 96  Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 97  Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# 98  Humidity = 70.00 %  Temperature = 22.00 C  Lig...
#
# [99 rows x 1 columns]

# %%
df1.iloc[0]
# Out:
# Humidity = 70.00 %  Temperature = 22.00 C  Light = 285 Lx  Soil moisture = -1.00 % Datetime: 220817_1216    Humidity = 70.00 %  Temperature = 22.00 C  Lig...
# Name: 0, dtype: object

# %%
l = []
for i in range(98):
    for t in df1.iloc[i][0].split():
        try:
            l.append(float(t))
        except ValueError:
            pass

# %%
l
# Out:
# [70.0,
#  22.0,
#  283.0,
#  2.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  278.0,
#  5.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  266.0,
#  2.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  264.0,
#  4.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  266.0,
#  5.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  275.0,
#  3.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  280.0,
#  4.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  282.0,
#  7.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  282.0,
#  7.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  282.0,
#  3.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  282.0,
#  7.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  283.0,
#  4.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  282.0,
#  2.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  281.0,
#  2.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  280.0,
#  0.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  280.0,
#  3.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  244.0,
#  4.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  224.0,
#  7.0,
#  2208171216.0,
#  70.0,
#  22.0,
#  259.0,
#  3.0,
# ...

# %%
humidity = []
for i in range(0,len(l),5):
    humidity.append(l[i])

# %%
humidity
# Out:
# [70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0]

# %%
temp = []
for i in range(1,len(l),5):
    temp.append(l[i])

# %%
temp
# Out:
# [22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  54.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0]

# %%
light = []
for i in range(2,len(l),5):
    light.append(l[i])

# %%
light
# Out:
# [283.0,
#  278.0,
#  266.0,
#  264.0,
#  266.0,
#  275.0,
#  280.0,
#  282.0,
#  282.0,
#  282.0,
#  282.0,
#  283.0,
#  282.0,
#  281.0,
#  280.0,
#  280.0,
#  244.0,
#  224.0,
#  259.0,
#  262.0,
#  262.0,
#  264.0,
#  264.0,
#  266.0,
#  266.0,
#  266.0,
#  266.0,
#  267.0,
#  284.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  283.0,
#  281.0,
#  281.0,
#  281.0,
#  281.0,
#  282.0,
#  283.0,
#  284.0,
#  285.0,
#  285.0,
#  286.0,
#  288.0,
#  288.0,
#  286.0,
#  288.0,
#  239.0,
#  194.0,
#  194.0,
#  194.0,
#  194.0,
#  194.0,
#  190.0,
#  190.0,
#  183.0,
#  191.0,
#  193.0,
#  251.0,
#  280.0,
#  280.0,
#  284.0,
#  284.0,
#  285.0,
#  286.0,
#  286.0,
#  285.0,
#  286.0,
#  286.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0,
#  285.0]

# %%
soil_moisture = []
for i in range(3,len(l),5):
    soil_moisture.append(l[i])

# %%
soil_moisture
# Out:
# [2.0,
#  5.0,
#  2.0,
#  4.0,
#  5.0,
#  3.0,
#  4.0,
#  7.0,
#  7.0,
#  3.0,
#  7.0,
#  4.0,
#  2.0,
#  2.0,
#  0.0,
#  3.0,
#  4.0,
#  7.0,
#  3.0,
#  7.0,
#  1.0,
#  0.0,
#  8.0,
#  6.0,
#  7.0,
#  7.0,
#  5.0,
#  5.0,
#  3.0,
#  2.0,
#  5.0,
#  6.0,
#  6.0,
#  1.0,
#  2.0,
#  0.0,
#  5.0,
#  7.0,
#  1.0,
#  -1.0,
#  0.0,
#  3.0,
#  3.0,
#  6.0,
#  5.0,
#  2.0,
#  1.0,
#  0.0,
#  2.0,
#  2.0,
#  2.0,
#  6.0,
#  4.0,
#  -2.0,
#  1.0,
#  1.0,
#  1.0,
#  0.0,
#  5.0,
#  6.0,
#  0.0,
#  3.0,
#  3.0,
#  5.0,
#  4.0,
#  2.0,
#  5.0,
#  6.0,
#  4.0,
#  3.0,
#  7.0,
#  1.0,
#  3.0,
#  3.0,
#  1.0,
#  2.0,
#  6.0,
#  3.0,
#  9.0,
#  5.0,
#  6.0,
#  3.0,
#  2.0,
#  3.0,
#  6.0,
#  -1.0,
#  6.0,
#  4.0,
#  3.0,
#  2.0,
#  9.0,
#  6.0,
#  2.0,
#  4.0,
#  7.0,
#  2.0,
#  2.0,
#  4.0]

# %%
time = []
for i in range(4,len(l),5):
    time.append(str(l[i])[6:10])

# %%
time
# Out:
# ['1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1216',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
#  '1217',
# ...

# %%
datetime_list = []
for i in range(4,len(l),5):
    datetime_list.append("20" + str(l[i])[0:6])

# %%
datetime_list
# Out:
# ['20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
#  '20220817',
# ...

# %%
from datetime import datetime
new_datetime = []
for i in datetime_list:
    new_datetime.append(datetime.strptime(i,'%Y%m%d').strftime('%Y-%m-%d'))

# %%
new_datetime
# Out:
# ['2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
#  '2022-08-17',
# ...

# %%
df2 = {"Humidity" : humidity, "Temp" : temp, "Light" : light, "Soil Moisture" : soil_moisture, "Date" : new_datetime,
      "Time" : time}

# %%
df2
# Out:
# {'Humidity': [70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0],
# ...

# %%
df2 = pd.DataFrame(data = df2)

# %%
df2
# Out:
#     Humidity  Temp  Light  Soil Moisture        Date  Time
# 0       70.0  22.0  283.0            2.0  2022-08-17  1216
# 1       70.0  22.0  278.0            5.0  2022-08-17  1216
# 2       70.0  22.0  266.0            2.0  2022-08-17  1216
# 3       70.0  22.0  264.0            4.0  2022-08-17  1216
# 4       70.0  22.0  266.0            5.0  2022-08-17  1216
# ..       ...   ...    ...            ...         ...   ...
# 93      70.0  22.0  285.0            4.0  2022-08-17  1217
# 94      70.0  22.0  285.0            7.0  2022-08-17  1217
# 95      70.0  22.0  285.0            2.0  2022-08-17  1217
# 96      70.0  22.0  285.0            2.0  2022-08-17  1217
# 97      70.0  22.0  285.0            4.0  2022-08-17  1217
#
# [98 rows x 6 columns]

# %%
type(df2.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df2.index, "Light", data=df2)
plt.title("Light against time")
plt.xlabel("Time")
plt.ylabel("Light lux")
# Out:
# Text(0, 0.5, 'Light lux')

# %%
plt.plot(df2.index, "Soil Moisture", data=df2)
plt.title("Soil moisture against time")
plt.xlabel("Time")
plt.ylabel("Soil Moisture")
# Out:
# Text(0, 0.5, 'Soil Moisture')
